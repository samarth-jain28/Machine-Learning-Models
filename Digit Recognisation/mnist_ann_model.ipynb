# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mnist_train = pd.read_csv("/train.csv")
mnist_test = pd.read_csv("/test.csv")

# %%
train_digit1 = np.asarray(mnist_train.iloc[0:1, 1:]).reshape(28, 28)
test_digit1 = np.asarray(mnist_test.iloc[4, 0:]).reshape(28, 28)
plt.subplot(1,2,1)
plt.imshow(train_digit1, cmap = plt.cm.gray_r)
plt.subplot(1,2,2)
plt.imshow(test_digit1, cmap = plt.cm.gray_r)

# %%
x_train = mnist_train.iloc[:, 1:]
y_train = np.asarray(mnist_train.iloc[:, 0])

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# %%
model = MLPClassifier(hidden_layer_sizes = (150, 100, 50))  # Created single hidden layer with 50 nodes
model.fit(x_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(150, 100, 50))

# %%
predict1 = model.predict(mnist_train.iloc[:,1: ])
predict2 = model.predict(mnist_test.iloc[:, 0:])
for i in range(10):
    print(predict2[i])
# Out:
# 2
# 0
# 9
# 9
# 3
# 9
# 0
# 3
# 0
# 3

# %%
print(classification_report(y_train, predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4132
#            1       1.00      1.00      1.00      4684
#            2       1.00      0.99      0.99      4177
#            3       0.99      0.99      0.99      4351
#            4       1.00      0.99      0.99      4072
#            5       1.00      1.00      1.00      3795
#            6       1.00      1.00      1.00      4137
#            7       1.00      0.99      1.00      4401
#            8       0.99      1.00      1.00      4063
#            9       0.99      1.00      0.99      4188
#
#     accuracy                           1.00     42000
#    macro avg       1.00      1.00      1.00     42000
# weighted avg       1.00      1.00      1.00     42000

# %%
for i in range(1):
    test_digit1 = np.asarray(mnist_test.iloc[i, 0:]).reshape(28, 28)
    plt.imshow(test_digit1, cmap = plt.cm.gray_r)
